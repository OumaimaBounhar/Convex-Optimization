# %%
from optimization_utils import *
from data_utils import *
import random
import numpy as np

random.seed(2000)
np.random.seed(2000)

# %% [markdown]
# # Part I

# %%
main_part_one(  dataset='CRIME', 
                lambda_val = 0.025,
                lr = 0.01,
                epochs = 100000,
                precision = 1e-32)
# Out:
# Computing closed form solution...
# Closed form solution : [-0.00606688 -0.06765984  0.04227379 -0.05051028  0.00900829  0.00738274
#   0.05327112  0.00062189 -0.06866269 -0.02765569 -0.04189036 -0.07153809
#  -0.02231165 -0.01448804  0.04519584 -0.0178682  -0.10276851  0.05177518
#  -0.15189519  0.00629718  0.03028716 -0.0979738   0.0552585   0.00082733
#   0.00272796  0.02310819 -0.00096192  0.00991003 -0.07280661  0.0137083
#   0.06064101  0.00485201 -0.00777229 -0.14492303 -0.06368051 -0.01675001
#   0.00964997 -0.01976969  0.04885391 -0.06110899 -0.01663479 -0.01364912
#  -0.02962395  0.06170892  0.01117696 -0.20687861 -0.03585333  0.02921665
#   0.00824923  0.00695331 -0.02136253 -0.08458132 -0.00148676  0.00986638
#   0.00731268  0.01013593  0.00600003 -0.06516343 -0.00101147  0.03315329
#   0.03863097 -0.00694394 -0.01566797 -0.06118987 -0.00422879  0.00958867
#  -0.06084784  0.00432778 -0.07717111  0.06161777  0.01803802  0.02493773
# ...

# %%
main_part_one(  dataset='ELECTRIC', 
                lambda_val = 0.85,
                lr = 0.01,
                epochs = 100,
                precision = 1e-32)
# Out:
# Computing closed form solution...
# Closed form solution : [ 0.32652002 -0.02464056  0.0097649   0.30298298 -0.13455115 -0.12748287]
# 100%|██████████| 100/100 [00:02<00:00, 37.94it/s]
# Gradient Descent Solution : [ 0.20240405  0.01100992  0.12388756  0.45096451 -0.08644111 -0.13337826]
# f(w*)= 0.1989553828709105  f(w_GD)= 0.2128912500835976  f(w_GD)-f(w*)= 0.013935867212687109

# %% [markdown]
# # Part II

# %%
from optimization_utils import *
from data_utils import *
import random
import numpy as np

random.seed(2000)
np.random.seed(2000)

# %% [markdown]
# **Computing Crime Dataset for different step sizes (the followin were the best)**

# %%
main_part_2(  dataset='CRIME', 
              lambda_val = 1,
              lr = 0.01,
              epochs = 200,
              precision = 1e-32)
# Out:
# 100%|██████████| 200/200 [00:01<00:00, 124.13it/s]
# Gradient Descent Solution : [1.47730353e-03 1.63685461e-02 7.45028287e-03 3.76559550e-03
#  1.06413518e-03 3.46024687e-03 1.18161896e-02 2.94516891e-03
#  1.18392022e-02 9.51956092e-03 5.29274651e-03 5.30721514e-03
#  1.24558340e-02 4.35975944e-03 1.72793182e-02 6.49060340e-03
#  1.08064866e-03 1.58705707e-02 4.65460114e-03 1.53931609e-02
#  0.07881499 0.08721945 0.01588321 0.1221018  0.15874663 0.16306145
#  0.09445826 0.23091753 0.20747182 0.0261364  0.00679627 0.23148881
#  0.12456673 0.09400857 0.10900607 0.10960217 0.24250605 0.22239304
#  0.21736873 0.1039011  0.02274074 0.11356696 0.06496704 0.23363079
#  0.06934089 0.05671949 0.11092199 0.13871557 0.06722501 0.1196164
#  0.05254956 0.06130277 0.12219713 0.01552828 0.24047228 0.02344658
#  0.07476277 0.21930551 0.13613542 0.11950301 0.06547685 0.09113935
# ...

# %% [markdown]
# **Computing Electric Dataset for different step sizes (the followin were the best)**

# %%
main_part_2(  dataset='ELECTRIC', 
              lambda_val = 1,
              lr = 0.0035,
              epochs = 200,
              precision = 1e-32)
# Out:
# 100%|██████████| 200/200 [03:07<00:00,  1.07it/s]
# Gradient Descent Solution : [0.13609888 0.13557535 0.08131417 0.13381305 0.16180203 0.06883386]
# 100%|██████████| 200/200 [00:05<00:00, 34.26it/s]
# Stochastic Gradient Descent Solution : [0.23134043 0.04836807 0.214402   0.19587446 0.17344695 0.18457574]
# Part II :  f(w_GD)= 0.09233950207733636  f(w_SGD)= 0.3160350950179578  f(w_GD)-f(w_SGD)= -0.2236955929406214

# %%
main_part_2(  dataset='ELECTRIC', 
              lambda_val = 1,
              lr = 0.0075,
              epochs = 200,
              precision = 1e-32)
# Out:
# 100%|██████████| 200/200 [03:08<00:00,  1.06it/s]
# Gradient Descent Solution : [0.03399163 0.00682831 0.00951275 0.03617649 0.03815677 0.02324803]
# 100%|██████████| 200/200 [00:06<00:00, 32.70it/s]
# Stochastic Gradient Descent Solution : [0.04370039 0.02543219 0.00960304 0.03999916 0.03595068 0.0047818 ]
# Part II :  f(w_GD)= 0.004597697150004508  f(w_SGD)= 0.12767529171121267  f(w_GD)-f(w_SGD)= -0.12307759456120816

# %%
main_part_2(  dataset='ELECTRIC', 
              lambda_val = 1,
              lr = 0.01,
              epochs = 200,
              precision = 1e-32)
# Out:
# 100%|██████████| 200/200 [03:10<00:00,  1.05it/s]
# Gradient Descent Solution : [0.0062947  0.00617489 0.00456985 0.00512079 0.01334494 0.00724267]
# 100%|██████████| 200/200 [00:05<00:00, 33.87it/s]
# Stochastic Gradient Descent Solution : [0.01317667 0.00712411 0.01406862 0.01430466 0.01233428 0.00431283]
# Part II :  f(w_GD)= 0.00035540212064870755  f(w_SGD)= 0.2504380490759106  f(w_GD)-f(w_SGD)= -0.2500826469552619

# %% [markdown]
# *The complexity for the electric data is higher than the one for crime data, as electric data has N = 2075259 while crime data has N = 1994. We can see the difference in terms of time taken to compute GD and SG algorithms for both datasets.*
